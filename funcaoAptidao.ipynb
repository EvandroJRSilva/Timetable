# %%
# FUNCAO DE APTIDAO
# A avaliacao de uma aula foi dada pelo somatoria dos pesos das restricoes multiplicado pela quantidade das restricoes que foram quebradas

#def aptipdaoAula():

# %%
class aula:
    def __init__(self, curso, disciplina, professor, turma, modalidade, turno, periodo):
        self.curso = curso
        self.disciplina = disciplina 
        self.professor =professor 
        self.turma = turma
        self.modalidade = modalidade 
        self.turno = turno
        self.periodo = periodo

# %%
# curso de ciencias da computacao
Sistemas_operacionais = aula("Ciencias da computacao","Sistemas operacionais", "Vinicius", 1, "Presencial", "manha", 3)
Codigo_de_alta_performance = aula("Ciencias da computacao","Codigo de alta performance", "Tiago", 1, "Presencial", "manha", 3)
Programacao_mobile = aula("Ciencias da computacao","Programacao mobile", "Igor", 1, "Presencial", "manha", 3)
Database_Aplication = aula("Ciencias da computacao","Database Aplication", "Marcos", 1, "Presencial", "manha", 3)
Rede_de_Computadores = aula("Ciencias da computacao","Rede de Computadores", "Evandro", 1, "Presencial", "manha", 3)
Arquitetura_de_Software = aula("Ciencias da computacao","Arquitetura de Software", "Karoline", 1, "Presencial", "manha", 3)
Logica_programacao = aula("Ciencias da computacao","Logica de programacao", "sem nome", 1, "online", "manha", 3)
Sistemas_computacionais = aula("Ciencias da computacao","Sistemas Computacionais", "sem nome", 1, "online", "manha", 3)
Desenvolvimento_Sustentavel = aula("Ciencias da computacao","Sistemas Computacionais", "sem nome", 1, "DOL", "manha", 3)
aula_vazia = aula(None,None,None,None,None,None,None)

# ADS
Projeto_banco_dados = aula("Analise e desenvolvimento de sistemas","Projeto de banco de dados","Marcos antonio", 1, "Presencial", "manha", 3)
Rede_computadores = aula("Analise e desenvolvimento de sistemas","Rede de computadores","sem nome", 1, "online", "manha", 3)

Org_arquitetura = aula("Analise e desenvolvimento de sistemas","Org e Arquitetura de computadores","Joselito", 1, "Presencial", "manha", 3)
Desenvolvimento_moveis = aula("Analise e desenvolvimento de sistemas","Desenvolvimento para dispositivos moveis", "Igor", 1, "Presencial", "manha", 3)
Backend_frameworks = aula("Analise e desenvolvimento de sistemas","Backend frameworks", "Karoline", 1, "Presencial", "manha", 3)
Empreendorismo = aula("Analise e desenvolvimento de sistemas","Empreendorismo", "sem nome", 1, "DOL", "manha", 3)

# %%
individuo = [
    [
        [aula_vazia,Sistemas_operacionais,Programacao_mobile,Rede_de_Computadores,Codigo_de_alta_performance,Desenvolvimento_Sustentavel],
        [aula_vazia,Sistemas_operacionais,Database_Aplication,Rede_de_Computadores,Codigo_de_alta_performance,Desenvolvimento_Sustentavel],
        [aula_vazia,Codigo_de_alta_performance,Database_Aplication,Programacao_mobile,Arquitetura_de_Software,Desenvolvimento_Sustentavel],
        [aula_vazia,Codigo_de_alta_performance,Database_Aplication,Programacao_mobile,Arquitetura_de_Software,Desenvolvimento_Sustentavel],
        [aula_vazia,aula_vazia,Logica_programacao,Sistemas_operacionais,Sistemas_computacionais,aula_vazia],
    ],
    [
        [Projeto_banco_dados,Projeto_banco_dados,Org_arquitetura,Backend_frameworks,Empreendorismo],
        [Projeto_banco_dados,Projeto_banco_dados,Org_arquitetura,Backend_frameworks,Empreendorismo],
        [Rede_computadores,Org_arquitetura,Desenvolvimento_moveis,Backend_frameworks,Empreendorismo],
        [aula_vazia,Org_arquitetura,Desenvolvimento_moveis,Backend_frameworks,Empreendorismo],
        [aula_vazia,aula_vazia,aula_vazia,aula_vazia,aula_vazia,aula_vazia],
    ]
]



def posicaoDeAula(horario, dia):
    d = 6
    posicao = horario * d + dia
    return posicao


def copiaAula(vetor):
    aula = posicaoDeAula(2, 2)
    for i in range(aula):
        vetor([[],[]])

# %%
# percorre um objeto aula especifico

aula = individuo[0][3][3]  # periodo 0, Dia 0, Aula 0

print("Curso:", aula.curso)
print("Disciplina:", aula.disciplina)
print("Professor:", aula.professor)
print("Turma:", aula.turma)
print("Modalidade:", aula.modalidade)
print("Turno:", aula.turno)
print("Período:", aula.periodo)
# Out:
# Curso: Ciencias da computacao
# Disciplina: Programacao mobile
# Professor: Igor
# Turma: 1
# Modalidade: Presencial
# Turno: manha
# Período: 3

# %%
# percorre o individuo inteiro mostrando os dados dos objetos aulas

for periodo_num, periodo in enumerate(individuo, start=1):
    for dia_num, dia in enumerate(periodo, start=1):
        for aula_num, aula in enumerate(dia, start=1):
            print(f"\nPeriodo {periodo_num}, Dia {dia_num}, Aula {aula_num}:")
            if aula.disciplina == "aula_vazia":
                print("(Vazio)")
            else:
                print(f"Disciplina: {aula.disciplina}")
                print(f"Professor: {aula.professor}")
                print(f"Turma: {aula.turma}")
                print(f"Turno: {aula.turno}")
# Out:
# Periodo 1, Dia 1, Aula 1:
# Disciplina: None
# Professor: None
# Turma: None
# Turno: None
#
# Periodo 1, Dia 1, Aula 2:
# Disciplina: Sistemas operacionais
# Professor: Vinicius
# Turma: 1
# Turno: manha
#
# Periodo 1, Dia 1, Aula 3:
# Disciplina: Programacao mobile
# Professor: Igor
# Turma: 1
# Turno: manha
#
# Periodo 1, Dia 1, Aula 4:
# Disciplina: Rede de Computadores
# Professor: Evandro
# Turma: 1
# Turno: manha
#
# Periodo 1, Dia 1, Aula 5:
# Disciplina: Codigo de alta performance
# Professor: Tiago
# Turma: 1
# Turno: manha
#
# Periodo 1, Dia 1, Aula 6:
# Disciplina: Sistemas Computacionais
# Professor: sem nome
# Turma: 1
# Turno: manha
#
# Periodo 1, Dia 2, Aula 1:
# Disciplina: None
# Professor: None
# Turma: None
# Turno: None
#
# Periodo 1, Dia 2, Aula 2:
# Disciplina: Sistemas operacionais
# Professor: Vinicius
# Turma: 1
# Turno: manha
#
# Periodo 1, Dia 2, Aula 3:
# Disciplina: Database Aplication
# Professor: Marcos
# Turma: 1
# Turno: manha
#
# Periodo 1, Dia 2, Aula 4:
# Disciplina: Rede de Computadores
# Professor: Evandro
# Turma: 1
# Turno: manha
#
# Periodo 1, Dia 2, Aula 5:
# Disciplina: Codigo de alta performance
# Professor: Tiago
# Turma: 1
# Turno: manha
#
# Periodo 1, Dia 2, Aula 6:
# Disciplina: Sistemas Computacionais
# Professor: sem nome
# Turma: 1
# Turno: manha
#
# Periodo 1, Dia 3, Aula 1:
# Disciplina: None
# Professor: None
# Turma: None
# Turno: None
#
# Periodo 1, Dia 3, Aula 2:
# Disciplina: Codigo de alta performance
# Professor: Tiago
# Turma: 1
# Turno: manha
#
# Periodo 1, Dia 3, Aula 3:
# Disciplina: Database Aplication
# Professor: Marcos
# Turma: 1
# Turno: manha
#
# Periodo 1, Dia 3, Aula 4:
# Disciplina: Programacao mobile
# Professor: Igor
# Turma: 1
# Turno: manha
#
# Periodo 1, Dia 3, Aula 5:
# Disciplina: Arquitetura de Software
# Professor: Karoline
# Turma: 1
# Turno: manha
#
# Periodo 1, Dia 3, Aula 6:
# Disciplina: Sistemas Computacionais
# Professor: sem nome
# Turma: 1
# Turno: manha
#
# Periodo 1, Dia 4, Aula 1:
# Disciplina: None
# Professor: None
# Turma: None
# Turno: None
#
# Periodo 1, Dia 4, Aula 2:
# Disciplina: Codigo de alta performance
# Professor: Tiago
# Turma: 1
# Turno: manha
#
# Periodo 1, Dia 4, Aula 3:
# Disciplina: Database Aplication
# Professor: Marcos
# Turma: 1
# Turno: manha
#
# Periodo 1, Dia 4, Aula 4:
# Disciplina: Programacao mobile
# Professor: Igor
# Turma: 1
# Turno: manha
#
# Periodo 1, Dia 4, Aula 5:
# Disciplina: Arquitetura de Software
# Professor: Karoline
# Turma: 1
# Turno: manha
#
# Periodo 1, Dia 4, Aula 6:
# Disciplina: Sistemas Computacionais
# Professor: sem nome
# Turma: 1
# Turno: manha
#
# Periodo 1, Dia 5, Aula 1:
# Disciplina: None
# Professor: None
# Turma: None
# Turno: None
#
# Periodo 1, Dia 5, Aula 2:
# Disciplina: None
# Professor: None
# Turma: None
# Turno: None
#
# Periodo 1, Dia 5, Aula 3:
# Disciplina: Logica de programacao
# Professor: sem nome
# Turma: 1
# Turno: manha
#
# Periodo 1, Dia 5, Aula 4:
# Disciplina: Sistemas operacionais
# Professor: Vinicius
# Turma: 1
# Turno: manha
#
# Periodo 1, Dia 5, Aula 5:
# Disciplina: Sistemas Computacionais
# Professor: sem nome
# Turma: 1
# Turno: manha
#
# Periodo 1, Dia 5, Aula 6:
# Disciplina: None
# Professor: None
# Turma: None
# Turno: None
#
# Periodo 2, Dia 1, Aula 1:
# Disciplina: Projeto de banco de dados
# Professor: Marcos antonio
# Turma: 1
# Turno: manha
#
# Periodo 2, Dia 1, Aula 2:
# Disciplina: Projeto de banco de dados
# Professor: Marcos antonio
# Turma: 1
# Turno: manha
#
# Periodo 2, Dia 1, Aula 3:
# Disciplina: Org e Arquitetura de computadores
# Professor: Joselito
# Turma: 1
# Turno: manha
#
# Periodo 2, Dia 1, Aula 4:
# Disciplina: Backend frameworks
# Professor: Karoline
# Turma: 1
# Turno: manha
#
# Periodo 2, Dia 1, Aula 5:
# Disciplina: Empreendorismo
# Professor: sem nome
# Turma: 1
# Turno: manha
#
# Periodo 2, Dia 2, Aula 1:
# Disciplina: Projeto de banco de dados
# Professor: Marcos antonio
# Turma: 1
# Turno: manha
#
# Periodo 2, Dia 2, Aula 2:
# Disciplina: Projeto de banco de dados
# Professor: Marcos antonio
# Turma: 1
# Turno: manha
#
# Periodo 2, Dia 2, Aula 3:
# Disciplina: Org e Arquitetura de computadores
# Professor: Joselito
# Turma: 1
# Turno: manha
#
# Periodo 2, Dia 2, Aula 4:
# Disciplina: Backend frameworks
# Professor: Karoline
# Turma: 1
# Turno: manha
#
# Periodo 2, Dia 2, Aula 5:
# Disciplina: Empreendorismo
# Professor: sem nome
# Turma: 1
# Turno: manha
#
# Periodo 2, Dia 3, Aula 1:
# Disciplina: Rede de computadores
# Professor: sem nome
# Turma: 1
# Turno: manha
#
# Periodo 2, Dia 3, Aula 2:
# Disciplina: Org e Arquitetura de computadores
# Professor: Joselito
# Turma: 1
# Turno: manha
#
# Periodo 2, Dia 3, Aula 3:
# Disciplina: Desenvolvimento para dispositivos moveis
# Professor: Igor
# Turma: 1
# Turno: manha
#
# Periodo 2, Dia 3, Aula 4:
# Disciplina: Backend frameworks
# Professor: Karoline
# Turma: 1
# Turno: manha
#
# Periodo 2, Dia 3, Aula 5:
# Disciplina: Empreendorismo
# Professor: sem nome
# Turma: 1
# Turno: manha
#
# Periodo 2, Dia 4, Aula 1:
# Disciplina: None
# Professor: None
# Turma: None
# Turno: None
#
# Periodo 2, Dia 4, Aula 2:
# Disciplina: Org e Arquitetura de computadores
# Professor: Joselito
# Turma: 1
# Turno: manha
#
# Periodo 2, Dia 4, Aula 3:
# Disciplina: Desenvolvimento para dispositivos moveis
# Professor: Igor
# Turma: 1
# Turno: manha
#
# Periodo 2, Dia 4, Aula 4:
# Disciplina: Backend frameworks
# Professor: Karoline
# Turma: 1
# Turno: manha
#
# Periodo 2, Dia 4, Aula 5:
# Disciplina: Empreendorismo
# Professor: sem nome
# Turma: 1
# Turno: manha
#
# Periodo 2, Dia 5, Aula 1:
# Disciplina: None
# Professor: None
# Turma: None
# Turno: None
#
# Periodo 2, Dia 5, Aula 2:
# Disciplina: None
# Professor: None
# Turma: None
# Turno: None
#
# Periodo 2, Dia 5, Aula 3:
# Disciplina: None
# Professor: None
# Turma: None
# Turno: None
#
# Periodo 2, Dia 5, Aula 4:
# Disciplina: None
# Professor: None
# Turma: None
# Turno: None
#
# Periodo 2, Dia 5, Aula 5:
# Disciplina: None
# Professor: None
# Turma: None
# Turno: None
#
# Periodo 2, Dia 5, Aula 6:
# Disciplina: None
# Professor: None
# Turma: None
# Turno: None
